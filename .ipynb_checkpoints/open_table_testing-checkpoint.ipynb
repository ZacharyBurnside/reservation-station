# %%
import requests
import pandas as pd

url = 'https://www.opentable.com/dapi/fe/gql?optype=query&opname=LolzViewAllRestaurants'

payload = {"operationName":"LolzViewAllRestaurants","variables":{"limit":30,"offset":30,"collectionToken":"H4sIAAAAAAAA_6tWMlKyUjIyMDLVNTDSNbAIMTS0Mja0MjBQ0lEyRpEBCpgABQwtgZIQeVMlKyMdJTOgoImBnrmZqbGOrrmxnqWphSVQ0gIoHOAaFOzv5-jjGeUaFB8Y6hoUCZSwBEooO-XnZ7vlF7lk5uWlFoXk52WmZ5QA5QyBVkbHAmmgTWmJOcWptQA30f9_oAAAAA==","tld":"com","requestedDate":"2025-02-08","requestedTime":"19:00","partySize":2,"correlationId":"95f14ed3-59da-467d-b9b3-98bb7b2797d6"},"extensions":{"persistedQuery":{"version":1,"sha256Hash":"3aa523d08a8dc0c27f5ccb2d99adfcea710477e451b5478f9a51a8fb80d252c5"}}}

headers = {user-agent:'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36 Edg/132.0.0.0,
           'x-csrf-token':'0b53a780-b2f2-474c-af49-af6fb2b0251b'}

response = requests.post(url, json = payload, headers = headers)

results = response.json()

# %%
results
